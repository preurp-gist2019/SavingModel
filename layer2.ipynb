# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K
import cartpole_mod
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import json


EPISODES = 300

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()
        self.train_info = []        # for Training accuracy & loss

    """Huber loss for Q Learning

    References: https://en.wikipedia.org/wiki/Huber_loss
                https://www.tensorflow.org/api_docs/python/tf/losses/huber_loss
    """

    def _huber_loss(self, y_true, y_pred, clip_delta=1.0):
        error = y_true - y_pred
        cond  = K.abs(error) <= clip_delta

        squared_loss = 0.5 * K.square(error)
        quadratic_loss = 0.5 * K.square(clip_delta) + clip_delta * (K.abs(error) - clip_delta)

        return K.mean(tf.where(cond, squared_loss, quadratic_loss))

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss=self._huber_loss,
                      optimizer=Adam(lr=self.learning_rate),
                     metrics=['accuracy'])
        return model

    def update_target_model(self):
        # copy weights from model to target_model
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        hist_batch = [] # for training accuracy & loss
        for state, action, reward, next_state, done in minibatch:
            target = self.model.predict(state)
            if done:
                target[0][action] = reward
            else:
                # a = self.model.predict(next_state)[0]
                t = self.target_model.predict(next_state)[0]
                target[0][action] = reward + self.gamma * np.amax(t)
                # target[0][action] = reward + self.gamma * t[np.argmax(a)]
            hist = self.model.fit(state, target, epochs=1, verbose=0)
            # hist has the length of batch size
            # Mean accuracy & loss should be calculated
            hist_batch.append([hist.history['acc'], hist.history['loss']])
            # self.model.fit(state, target, epochs=1, verbose=0)                 #######필요한지 확인바람
        
        hist_batch = np.array(hist_batch)
        acc_loss = [np.mean(hist_batch[:,0]), np.mean(hist_batch[:,1])]
        self.train_info.append(acc_loss)    # Save the training acc & loss
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def get_history(self):       
        data = self.train_info
        self.train_info = []  # For new episode, it should be cleared
        return data
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)


if __name__ == "__main__":
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.3
    set_session(tf.Session(config=config))
    env = gym.make('CartPole-v3')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)
    #agent.load("./save/cartpole-ddqn.h5")
    done = False
    batch_size = 32
    
    
    history = {}
    history['score'] = []
    history['epsilon'] = []
    temp_score = 0
    temp_epsilon = 0

    
    records = np.zeros((1,2))
    
    trialnumber = "layer_2"#.format(agent.epsilon) #이부분을 자기가 바꿀것!
    
    #Make the bestscore file into 1
    i = 1
    f = open("./save/cartpole_ddqn_Bestscore_{0}.txt".format(trialnumber), 'w')
    f.write("{}" .format(i))
    f.close()
    
    #If bestscore is bigger than 50, epsilon must be 0.1. Only one time
    #f = open("./save/cartpole_ddqn_Bestscore.txt", 'r')
    #exscore = float(f.readline()) 
    #f.close()
    #if exscore >= 50 :
    #    agent.epsilon = 0.1
    
    for e in range(EPISODES):
        #agent.load("./save/cartpole-ddqn.h5")
        #done = False
        batch_size = 32
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        temp_epsilon = 0
        tmep_score = 0
        for time in range(500):
            # env.render()
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10
            next_state = np.reshape(next_state, [1, state_size])
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                agent.update_target_model()
                print("episode: {}/{}, score: {}, e: {:.2}"
                      .format(e, EPISODES, time, agent.epsilon))
                temp_epsilon = agent.epsilon
                temp_score = time
                if e == 0:
                    records[0] = np.array([e, time])
                else:
                    records = np.concatenate((records, [[e, time]]), axis=0)
                break
            if len(agent.memory) > batch_size:
                agent.replay(batch_size)
        #Save the ex-bestscore to continue next time        
        if records[-1,1] >= np.amax(records[:,1]):
            f = open("./save/cartpole_ddqn_Bestscore_{0}.txt".format(trialnumber), 'r')
            line = float(f.readline())
            f.close()
            if records[-1,1] >= line :
                f = open("./save/cartpole_ddqn_Bestscore_{0}.txt".format(trialnumber), 'w')
                f.write("{}" .format(records[-1,1]))
                f.close()
                agent.save("./save/cartpole-ddqn_{0}.h5".format(trialnumber))
            print("Best model saved - episode: {}, score: {}".format(records[-1,0], records[-1,1]))
        history[e] = agent.get_history()
        history['score'].append(temp_score)
        history['epsilon'].append(temp_epsilon)
    json = json.dumps(history)
    f = open("./logs/history_{0}.json".format(trialnumber), 'w')
    f.write(json)
    f.close()
        # if e % 10 == 0:
        #     agent.save("./save/cartpole-ddqn.h5")
# Out:
# Using TensorFlow backend.
# episode: 0/300, score: 17, e: 1.0
# Best model saved - episode: 0.0, score: 17.0
# episode: 1/300, score: 28, e: 0.87
# Best model saved - episode: 1.0, score: 28.0
# episode: 2/300, score: 13, e: 0.76
# episode: 3/300, score: 21, e: 0.62
# episode: 4/300, score: 22, e: 0.49
# episode: 5/300, score: 20, e: 0.4
# episode: 6/300, score: 12, e: 0.36
# episode: 7/300, score: 30, e: 0.27
# Best model saved - episode: 7.0, score: 30.0
# episode: 8/300, score: 25, e: 0.21
# episode: 9/300, score: 53, e: 0.12
# Best model saved - episode: 9.0, score: 53.0
# episode: 10/300, score: 78, e: 0.055
# Best model saved - episode: 10.0, score: 78.0
# episode: 11/300, score: 59, e: 0.031
# episode: 12/300, score: 81, e: 0.014
# Best model saved - episode: 12.0, score: 81.0
# episode: 13/300, score: 80, e: 0.0099
# episode: 14/300, score: 93, e: 0.0099
# Best model saved - episode: 14.0, score: 93.0
# episode: 15/300, score: 80, e: 0.0099
# episode: 16/300, score: 108, e: 0.0099
# Best model saved - episode: 16.0, score: 108.0
# episode: 17/300, score: 77, e: 0.0099
# episode: 18/300, score: 100, e: 0.0099
# episode: 19/300, score: 122, e: 0.0099
# Best model saved - episode: 19.0, score: 122.0
# episode: 20/300, score: 97, e: 0.0099
# episode: 21/300, score: 85, e: 0.0099
# episode: 22/300, score: 103, e: 0.0099
# episode: 23/300, score: 86, e: 0.0099
# episode: 24/300, score: 78, e: 0.0099
# episode: 25/300, score: 96, e: 0.0099
# episode: 26/300, score: 100, e: 0.0099
# episode: 27/300, score: 97, e: 0.0099
# episode: 28/300, score: 90, e: 0.0099
# episode: 29/300, score: 106, e: 0.0099
# episode: 30/300, score: 94, e: 0.0099
# episode: 31/300, score: 77, e: 0.0099
# episode: 32/300, score: 145, e: 0.0099
# Best model saved - episode: 32.0, score: 145.0
# episode: 33/300, score: 71, e: 0.0099
# episode: 34/300, score: 60, e: 0.0099
# episode: 35/300, score: 66, e: 0.0099
# episode: 36/300, score: 26, e: 0.0099
# episode: 37/300, score: 69, e: 0.0099
# episode: 38/300, score: 91, e: 0.0099
# episode: 39/300, score: 61, e: 0.0099
# episode: 40/300, score: 34, e: 0.0099
# episode: 41/300, score: 75, e: 0.0099
# episode: 42/300, score: 117, e: 0.0099
# episode: 43/300, score: 36, e: 0.0099
# episode: 44/300, score: 125, e: 0.0099
# episode: 45/300, score: 94, e: 0.0099
# episode: 46/300, score: 101, e: 0.0099
# episode: 47/300, score: 106, e: 0.0099
# episode: 48/300, score: 109, e: 0.0099
# episode: 49/300, score: 27, e: 0.0099
# episode: 50/300, score: 173, e: 0.0099
# Best model saved - episode: 50.0, score: 173.0
# episode: 51/300, score: 128, e: 0.0099
# episode: 52/300, score: 78, e: 0.0099
# episode: 53/300, score: 71, e: 0.0099
# episode: 54/300, score: 54, e: 0.0099
# episode: 55/300, score: 162, e: 0.0099
# episode: 56/300, score: 58, e: 0.0099
# episode: 57/300, score: 15, e: 0.0099
# episode: 58/300, score: 29, e: 0.0099
# episode: 59/300, score: 20, e: 0.0099
# episode: 60/300, score: 29, e: 0.0099
# episode: 61/300, score: 66, e: 0.0099
# episode: 62/300, score: 69, e: 0.0099
# episode: 63/300, score: 37, e: 0.0099
# episode: 64/300, score: 109, e: 0.0099
# episode: 65/300, score: 98, e: 0.0099
# episode: 66/300, score: 146, e: 0.0099
# episode: 67/300, score: 208, e: 0.0099
# Best model saved - episode: 67.0, score: 208.0
# episode: 68/300, score: 116, e: 0.0099
# episode: 69/300, score: 107, e: 0.0099
# episode: 70/300, score: 102, e: 0.0099
# episode: 71/300, score: 98, e: 0.0099
# episode: 72/300, score: 89, e: 0.0099
# episode: 73/300, score: 113, e: 0.0099
# episode: 74/300, score: 111, e: 0.0099
# episode: 75/300, score: 103, e: 0.0099
# episode: 76/300, score: 122, e: 0.0099
# episode: 77/300, score: 109, e: 0.0099
# episode: 78/300, score: 115, e: 0.0099
# episode: 79/300, score: 111, e: 0.0099
# episode: 80/300, score: 109, e: 0.0099
# episode: 81/300, score: 68, e: 0.0099
# episode: 82/300, score: 78, e: 0.0099
# episode: 83/300, score: 18, e: 0.0099
# episode: 84/300, score: 108, e: 0.0099
# episode: 85/300, score: 10, e: 0.0099
# episode: 86/300, score: 117, e: 0.0099
# episode: 87/300, score: 229, e: 0.0099
# Best model saved - episode: 87.0, score: 229.0
# episode: 88/300, score: 165, e: 0.0099
# episode: 89/300, score: 129, e: 0.0099
# episode: 90/300, score: 88, e: 0.0099
# episode: 91/300, score: 156, e: 0.0099
# episode: 92/300, score: 198, e: 0.0099
# episode: 93/300, score: 108, e: 0.0099
# episode: 94/300, score: 112, e: 0.0099
# episode: 95/300, score: 100, e: 0.0099
# episode: 96/300, score: 94, e: 0.0099
# episode: 97/300, score: 118, e: 0.0099
# episode: 98/300, score: 123, e: 0.0099
# episode: 99/300, score: 28, e: 0.0099
# episode: 100/300, score: 122, e: 0.0099
# episode: 101/300, score: 120, e: 0.0099
# episode: 102/300, score: 110, e: 0.0099
# episode: 103/300, score: 111, e: 0.0099
# episode: 104/300, score: 120, e: 0.0099
# episode: 105/300, score: 106, e: 0.0099
# episode: 106/300, score: 125, e: 0.0099
# episode: 107/300, score: 98, e: 0.0099
# episode: 108/300, score: 75, e: 0.0099
# episode: 109/300, score: 41, e: 0.0099
# episode: 110/300, score: 46, e: 0.0099
# episode: 111/300, score: 192, e: 0.0099
# episode: 112/300, score: 26, e: 0.0099
# episode: 113/300, score: 117, e: 0.0099
# episode: 114/300, score: 66, e: 0.0099
# episode: 115/300, score: 25, e: 0.0099
# episode: 116/300, score: 15, e: 0.0099
# episode: 117/300, score: 15, e: 0.0099
# episode: 118/300, score: 16, e: 0.0099
# episode: 119/300, score: 21, e: 0.0099
# episode: 120/300, score: 61, e: 0.0099
# episode: 121/300, score: 88, e: 0.0099
# episode: 122/300, score: 89, e: 0.0099
# episode: 123/300, score: 136, e: 0.0099
# episode: 124/300, score: 155, e: 0.0099
# episode: 125/300, score: 98, e: 0.0099
# episode: 126/300, score: 123, e: 0.0099
# episode: 127/300, score: 51, e: 0.0099
# episode: 128/300, score: 134, e: 0.0099
# episode: 129/300, score: 358, e: 0.0099
# Best model saved - episode: 129.0, score: 358.0
# episode: 130/300, score: 99, e: 0.0099
# episode: 131/300, score: 112, e: 0.0099
# episode: 132/300, score: 113, e: 0.0099
# episode: 133/300, score: 121, e: 0.0099
# episode: 134/300, score: 129, e: 0.0099
# episode: 135/300, score: 105, e: 0.0099
# episode: 136/300, score: 77, e: 0.0099
# episode: 137/300, score: 90, e: 0.0099
# episode: 138/300, score: 26, e: 0.0099
# episode: 139/300, score: 13, e: 0.0099
# episode: 140/300, score: 11, e: 0.0099
# episode: 141/300, score: 25, e: 0.0099
# episode: 142/300, score: 45, e: 0.0099
# episode: 143/300, score: 12, e: 0.0099
# episode: 144/300, score: 36, e: 0.0099
# episode: 145/300, score: 36, e: 0.0099
# episode: 146/300, score: 129, e: 0.0099
# episode: 147/300, score: 90, e: 0.0099
# episode: 148/300, score: 36, e: 0.0099
# episode: 149/300, score: 68, e: 0.0099
# episode: 150/300, score: 95, e: 0.0099
# episode: 151/300, score: 132, e: 0.0099
# episode: 152/300, score: 160, e: 0.0099
# episode: 153/300, score: 160, e: 0.0099
# episode: 154/300, score: 137, e: 0.0099
# episode: 155/300, score: 154, e: 0.0099
# episode: 156/300, score: 225, e: 0.0099
# episode: 157/300, score: 63, e: 0.0099
# episode: 158/300, score: 184, e: 0.0099
# episode: 159/300, score: 136, e: 0.0099
# episode: 160/300, score: 83, e: 0.0099
# episode: 161/300, score: 186, e: 0.0099
# episode: 162/300, score: 100, e: 0.0099
# episode: 163/300, score: 110, e: 0.0099
# episode: 164/300, score: 130, e: 0.0099
# episode: 165/300, score: 112, e: 0.0099
# episode: 166/300, score: 113, e: 0.0099
# episode: 167/300, score: 90, e: 0.0099
# episode: 168/300, score: 130, e: 0.0099
# episode: 169/300, score: 115, e: 0.0099
# episode: 171/300, score: 101, e: 0.0099
# episode: 172/300, score: 120, e: 0.0099
# episode: 173/300, score: 111, e: 0.0099
# episode: 174/300, score: 251, e: 0.0099
# episode: 175/300, score: 123, e: 0.0099
# episode: 176/300, score: 114, e: 0.0099
# episode: 177/300, score: 49, e: 0.0099
# episode: 178/300, score: 43, e: 0.0099
# episode: 179/300, score: 103, e: 0.0099
# episode: 180/300, score: 78, e: 0.0099
# episode: 181/300, score: 100, e: 0.0099
# episode: 182/300, score: 68, e: 0.0099
# episode: 183/300, score: 276, e: 0.0099
# episode: 184/300, score: 137, e: 0.0099
# episode: 185/300, score: 97, e: 0.0099
# episode: 186/300, score: 170, e: 0.0099
# episode: 187/300, score: 114, e: 0.0099
# episode: 188/300, score: 124, e: 0.0099
# episode: 189/300, score: 98, e: 0.0099
# episode: 190/300, score: 72, e: 0.0099
# episode: 191/300, score: 107, e: 0.0099
# episode: 192/300, score: 105, e: 0.0099
# episode: 193/300, score: 75, e: 0.0099
# episode: 194/300, score: 172, e: 0.0099
# episode: 195/300, score: 137, e: 0.0099
# episode: 196/300, score: 138, e: 0.0099
# episode: 197/300, score: 132, e: 0.0099
# episode: 198/300, score: 111, e: 0.0099
# episode: 199/300, score: 102, e: 0.0099
# episode: 200/300, score: 102, e: 0.0099
# episode: 201/300, score: 97, e: 0.0099
# episode: 202/300, score: 148, e: 0.0099
# episode: 203/300, score: 114, e: 0.0099
# episode: 204/300, score: 60, e: 0.0099
# episode: 205/300, score: 104, e: 0.0099
# episode: 206/300, score: 115, e: 0.0099
# episode: 207/300, score: 98, e: 0.0099
# episode: 208/300, score: 217, e: 0.0099
# episode: 209/300, score: 171, e: 0.0099
# episode: 210/300, score: 98, e: 0.0099
# episode: 211/300, score: 50, e: 0.0099
# episode: 212/300, score: 208, e: 0.0099
# episode: 213/300, score: 189, e: 0.0099
# episode: 214/300, score: 142, e: 0.0099
# episode: 215/300, score: 196, e: 0.0099
# episode: 216/300, score: 17, e: 0.0099
# episode: 217/300, score: 220, e: 0.0099
# episode: 218/300, score: 17, e: 0.0099
# episode: 219/300, score: 117, e: 0.0099
# episode: 220/300, score: 165, e: 0.0099
# episode: 221/300, score: 171, e: 0.0099
# episode: 222/300, score: 146, e: 0.0099
# episode: 223/300, score: 15, e: 0.0099
# episode: 224/300, score: 115, e: 0.0099
# episode: 225/300, score: 134, e: 0.0099
# episode: 226/300, score: 96, e: 0.0099
# episode: 227/300, score: 163, e: 0.0099
# episode: 228/300, score: 160, e: 0.0099
# episode: 229/300, score: 101, e: 0.0099
# episode: 230/300, score: 32, e: 0.0099
# episode: 231/300, score: 129, e: 0.0099
# episode: 232/300, score: 126, e: 0.0099
# episode: 233/300, score: 198, e: 0.0099
# episode: 235/300, score: 185, e: 0.0099
# episode: 236/300, score: 136, e: 0.0099
# episode: 237/300, score: 186, e: 0.0099
# episode: 238/300, score: 241, e: 0.0099
# episode: 239/300, score: 58, e: 0.0099
# episode: 240/300, score: 24, e: 0.0099
# episode: 241/300, score: 52, e: 0.0099
# episode: 242/300, score: 82, e: 0.0099
# episode: 243/300, score: 230, e: 0.0099
# episode: 244/300, score: 21, e: 0.0099
# episode: 245/300, score: 109, e: 0.0099
# episode: 246/300, score: 12, e: 0.0099
# episode: 247/300, score: 163, e: 0.0099
# episode: 248/300, score: 127, e: 0.0099
# episode: 249/300, score: 177, e: 0.0099
# episode: 250/300, score: 173, e: 0.0099
# episode: 251/300, score: 204, e: 0.0099
# episode: 253/300, score: 257, e: 0.0099
# episode: 256/300, score: 352, e: 0.0099
# episode: 257/300, score: 83, e: 0.0099
# episode: 258/300, score: 261, e: 0.0099
# episode: 259/300, score: 16, e: 0.0099
# episode: 260/300, score: 406, e: 0.0099
# Best model saved - episode: 260.0, score: 406.0
# episode: 261/300, score: 176, e: 0.0099
# episode: 262/300, score: 44, e: 0.0099
# episode: 263/300, score: 26, e: 0.0099
# episode: 264/300, score: 28, e: 0.0099
# episode: 265/300, score: 66, e: 0.0099
# episode: 266/300, score: 15, e: 0.0099
# episode: 267/300, score: 87, e: 0.0099
# episode: 268/300, score: 13, e: 0.0099
# episode: 269/300, score: 14, e: 0.0099
# episode: 270/300, score: 12, e: 0.0099
# episode: 271/300, score: 15, e: 0.0099
# episode: 272/300, score: 13, e: 0.0099
# episode: 273/300, score: 18, e: 0.0099
# episode: 274/300, score: 120, e: 0.0099
# episode: 275/300, score: 49, e: 0.0099
# episode: 276/300, score: 21, e: 0.0099
# episode: 277/300, score: 15, e: 0.0099
# episode: 278/300, score: 259, e: 0.0099
# episode: 279/300, score: 441, e: 0.0099
# Best model saved - episode: 279.0, score: 441.0
# episode: 280/300, score: 148, e: 0.0099
# episode: 281/300, score: 132, e: 0.0099
# episode: 282/300, score: 127, e: 0.0099
# episode: 283/300, score: 117, e: 0.0099
# episode: 284/300, score: 123, e: 0.0099
# episode: 285/300, score: 124, e: 0.0099
# episode: 286/300, score: 108, e: 0.0099
# episode: 287/300, score: 172, e: 0.0099
# episode: 288/300, score: 159, e: 0.0099
# episode: 289/300, score: 80, e: 0.0099
# episode: 290/300, score: 28, e: 0.0099
# episode: 291/300, score: 17, e: 0.0099
# episode: 292/300, score: 36, e: 0.0099
# episode: 293/300, score: 57, e: 0.0099
# episode: 294/300, score: 12, e: 0.0099
# episode: 295/300, score: 109, e: 0.0099
# episode: 296/300, score: 39, e: 0.0099
# episode: 297/300, score: 105, e: 0.0099
# episode: 298/300, score: 76, e: 0.0099
# episode: 299/300, score: 15, e: 0.0099
